# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = [9721, 7064, 1187, 4123, 2171, 2300, 4031, 962, 5435, 1345, 2862, 2595, 904]

# %%
data = np.array(data)

# %%
data.sum() - data[0]
# Out:
# 34979

# %%
plt.figure(figsize=(4, 3)) 
plt.bar(['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B'], data[1:], color='black')
plt.tight_layout()
plt.savefig('hist_keys.png')
plt.show()
